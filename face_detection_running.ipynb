# %%
# !pip install cmake dlib
# Out:
# Requirement already satisfied: cmake in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (3.25.2)
# Collecting dlib
#   Using cached dlib-19.24.0.tar.gz (3.2 MB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py) ... done
#   Created wheel for dlib: filename=dlib-19.24.0-cp38-cp38-macosx_10_15_x86_64.whl size=3538547 sha256=4ab606002b7b25d647bc1bfb573d63c216411c4594934b4bbf3217f81b05ebca
#   Stored in directory: /Users/shrey/Library/Caches/pip/wheels/4c/d8/2d/a83b10e7bf10cd7d8bef36bf4dcd15b0c9ebf98f990bc984dd
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-19.24.0

# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: dlib>=19.7 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from face_recognition) (19.24.0)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from face_recognition) (9.4.0)
# Collecting Click>=6.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: face-recognition-models>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from face_recognition) (1.24.2)
# Installing collected packages: Click, face_recognition
# Successfully installed Click-8.1.3 face_recognition-1.3.0

# %%
import face_recognition
import cv2
import numpy as np
import glob
import os
import logging
import datetime

# %%
IMAGES_PATH = '/Users/shrey/Desktop/XYZZZZZ/image'
CROPPED_IMAGES_PATH = '/Users/shrey/Desktop/XYZZZZZ/cropeed'
CAMERA_DEVICE_ID = 0
MAX_DISTANCE = 0.6

# %%
def get_face_embeddings_from_image(image, convert_to_rgb=False):
    """
    Take a raw image and run both the face detection and face embedding model on it
    """
    
    # Convert from BGR to RGB if needed
    if convert_to_rgb:
        image = image[:, :, ::-1]
        
    # Run the face detection model to find face locations
    face_locations = face_recognition.face_locations(image)
    
    # Run the embedding model to get face embeddings for the supplied locations
    face_embeddings = face_recognition.face_encodings(image, face_locations)
    
    return face_locations, face_embeddings

# %%
def setup_database():
    """
    Load reference images and create a database of their face encodings
    """
    database = {}
    
    for filename in glob.glob(os.path.join('/Users/shrey/Desktop/XYZZZZZ/image','*.jpeg')):
        # Load image
        image_rgb = face_recognition.load_image_file(filename)
        
        # Use the name in the filename as the identity key
        identity = os.path.splitext(os.path.basename(filename))[0]
        
        # Get the face encoding and link it to the identity
        locations, encodings = get_face_embeddings_from_image(image_rgb)
        database[identity] = encodings[0]
    
    return database

# %%
def paint_detected_face_on_image(frame, location, name=None):
    """
    Paint a rectangle around the face and write the name
    """
    # unpack the coordinates from the location tuple
    top, right, bottom, left = location
    
    if name is None:
        name = 'Unknown'
        color = (0, 0, 255)  # red for unrecognized face
    else:
        color = (0, 128, 0)  # dark green for recognized face
        
    # Draw a box around the face
    cv2.rectangle(frame, (left, top), (right, bottom), color, 2)
    
    # Draw a label with a name below the face
    cv2.rectangle(frame, (left, bottom + 15), (right, bottom), color, cv2.FILLED)
    cv2.putText(frame, name, (left + 6, bottom + 12), cv2.FONT_HERSHEY_DUPLEX, 0.5, (255, 255, 255), 1)

# %%
def click_event(event, x, y, flags, params):
    """
    Crop an image based on the clicked detected face
    """

    # event is triggered with a mouse click
    if event == cv2.EVENT_LBUTTONUP:
        for location in face_locations:

            # unpack the coordinates from the location tuple
            top, right, bottom, left = location
            if (top < y < bottom) and  (left < x < right):
                frame_copy = np.copy(frame)
                roi = frame_copy[top:bottom, left:right]

                # give a unique name for the cropped image
                currentDT = datetime.datetime.now()
                cropped_name = os.path.join('/Users/shrey/Desktop/XYZZZZZ/cropeed', loc_name_dict[location] + '_' + str(currentDT) + '.jpeg')

                # save the cropped image
                cv2.imwrite(cropped_name, roi)

                # show the cropped image
                crop = cv2.imread(cropped_name)
                cv2.imshow('cropped image', crop)

                # re-run the run_face_recognition function
                run_face_recognition(database)

# %%
def run_face_recognition(database):
    """
    Start the face recognition via webcam
    """
    
    global face_locations
    global frame
    global name
    global loc_name_dict

    # Open a connection to the camera
    video_capture = cv2.VideoCapture(CAMERA_DEVICE_ID)
    
    # The face_recognition library uses keys and values of your database separately
    known_face_encodings = list(database.values())
    known_face_names = list(database.keys())

    
    while video_capture.isOpened():
        
        # Capture frame-by-frame
        ret, frame = video_capture.read()
        frame = cv2.resize(frame, None, fx=0.5, fy=0.5)
        
        if not ret:
            logging.error("Could not read frame from camera. Stopping video capture.")
            break
        
        # Run detection and embedding models
        face_locations, face_encodings = get_face_embeddings_from_image(frame, convert_to_rgb=True)

        # Build a dictionary to pair the location with the name of the detected face 
        loc_name_dict = dict()
        
        # Loop through each face in this frame of video and see if there's a match
        for location, face_encoding in zip(face_locations, face_encodings):
            
            # get the distances from this encoding to those of all reference images
            distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            
            # select the closest match (smallest distance) if it's below the threshold value
            if np.any(distances <= MAX_DISTANCE):
                best_match_idx = np.argmin(distances)
                name = known_face_names[best_match_idx]
            else:
                name = None
            
            # Pair the location with the name of the detected face inside a dictionary
            loc_name_dict[location] = name
            
            # show recognition info on the image
            paint_detected_face_on_image(frame, location, name)
            
        # Display the resulting image
        cv2.imshow('frame', frame)

        # Crop image if triggered by a mouse click
        cv2.setMouseCallback('frame', click_event)
    
        # Hit 'q' on the keyboard to stop the loop
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
            
    # When everything done, release the capture
    video_capture.release()
    cv2.destroyAllWindows()

# %%
database = setup_database()
run_face_recognition(database)
# Out:
# 1   HIToolbox                           0x00007ff81dade726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81dade2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff81da82908 SetMenuBarObscured + 408
# 4   HIToolbox                           0x00007ff81da824ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 5   HIToolbox                           0x00007ff81da7c996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 6   HIToolbox                           0x00007ff81da44bd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff81da7c3e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff81da6b3ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff81da6b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff81726e2f3 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff81726d174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  cv2.abi3.so                         0x00000001229224af cvWaitKey + 319
# 13  cv2.abi3.so                         0x000000012291bcb4 _ZN2cv9waitKeyExEi + 148
# 14  cv2.abi3.so                         0x000000012291bd84 _ZN2cv7waitKeyEi + 36
# 15  cv2.abi3.so                         0x0000000121b88014 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  Python                              0x000000010d454b18 cfunction_call_varargs + 120
# 17  Python                              0x000000010d454585 _PyObject_MakeTpCall + 373
# 18  Python                              0x000000010d521835 call_function + 533
# 19  Python                              0x000000010d51e5ed _PyEval_EvalFrameDefault + 25677
# 20  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 21  Python                              0x000000010d5217dc call_function + 444
# 22  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 23  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 24  Python                              0x000000010d5180c4 PyEval_EvalCode + 100
# 25  Python                              0x000000010d5154b2 builtin_exec + 626
# 26  Python                              0x000000010d49081f cfunction_vectorcall_FASTCALL + 175
# 27  Python                              0x000000010d5217dc call_function + 444
# 28  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 29  Python                              0x000000010d4651ae gen_send_ex + 206
# 30  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 31  Python                              0x000000010d4651ae gen_send_ex + 206
# 32  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 33  Python                              0x000000010d4651ae gen_send_ex + 206
# 34  Python                              0x000000010d45df74 method_vectorcall_O + 260
# 35  Python                              0x000000010d5217dc call_function + 444
# 36  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 37  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 38  Python                              0x000000010d5217dc call_function + 444
# 39  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 40  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 41  Python                              0x000000010d5217dc call_function + 444
# 42  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 43  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 44  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 45  Python                              0x000000010d45767c method_vectorcall + 396
# 46  Python                              0x000000010d4548ad PyVectorcall_Call + 109
# 47  Python                              0x000000010d51eaf8 _PyEval_EvalFrameDefault + 26968
# 48  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 49  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 50  Python                              0x000000010d45759a method_vectorcall + 170
# 51  Python                              0x000000010d5217dc call_function + 444
# 52  Python                              0x000000010d51e714 _PyEval_EvalFrameDefault + 25972
# 53  Python                              0x000000010d4651ae gen_send_ex + 206
# 54  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 55  Python                              0x000000010d4651ae gen_send_ex + 206
# 56  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 57  Python                              0x000000010d4651ae gen_send_ex + 206
# 58  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 59  Python                              0x000000010d4651ae gen_send_ex + 206
# 60  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 61  Python                              0x000000010d4651ae gen_send_ex + 206
# 62  _asyncio.cpython-38-darwin.so       0x000000010d400ef1 task_step + 833
# 63  _asyncio.cpython-38-darwin.so       0x000000010d400b4e TaskWakeupMethWrapper_call + 430
# 64  Python                              0x000000010d454585 _PyObject_MakeTpCall + 373
# 65  Python                              0x000000010d53e35d context_run + 253
# 66  Python                              0x000000010d4908f4 cfunction_vectorcall_FASTCALL_KEYWORDS + 132
# 67  Python                              0x000000010d4548ad PyVectorcall_Call + 109
# 68  Python                              0x000000010d51ec6b _PyEval_EvalFrameDefault + 27339
# 69  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 70  Python                              0x000000010d5217dc call_function + 444
# 71  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 72  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 73  Python                              0x000000010d5217dc call_function + 444
# 74  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 75  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 76  Python                              0x000000010d5217dc call_function + 444
# 77  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 78  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 79  Python                              0x000000010d5217dc call_function + 444
# 80  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 81  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 82  Python                              0x000000010d5217dc call_function + 444
# 83  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 84  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 85  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 86  Python                              0x000000010d45759a method_vectorcall + 170
# 87  Python                              0x000000010d5217dc call_function + 444
# 88  Python                              0x000000010d51e5ed _PyEval_EvalFrameDefault + 25677
# 89  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 90  Python                              0x000000010d5180c4 PyEval_EvalCode + 100
# 91  Python                              0x000000010d5154b2 builtin_exec + 626
# 92  Python                              0x000000010d49081f cfunction_vectorcall_FASTCALL + 175
# 93  Python                              0x000000010d5217dc call_function + 444
# 94  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 95  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 96  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 97  Python                              0x000000010d5217dc call_function + 444
# 98  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 99  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 100 Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 101 Python                              0x000000010d4548ad PyVectorcall_Call + 109
# 102 Python                              0x000000010d584a96 pymain_run_module + 182
# 103 Python                              0x000000010d58405d Py_RunMain + 1085
# 104 Python                              0x000000010d5847cf pymain_main + 223
# 105 Python                              0x000000010d5849cb Py_BytesMain + 43
# 106 dyld                                0x00007ff813d11310 start + 2432
# 1   HIToolbox                           0x00007ff81da6b0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81daa7638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff818d4c23d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff818d4a7f3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff819059686 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff818e75aec SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff81da78156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff81da780fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff81414d410 __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff8141200b1 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff81411ffee __CFRunLoopDoSource1 + 540
# 12  CoreFoundation                      0x00007ff81411ec6b __CFRunLoopRun + 2705
# 13  CoreFoundation                      0x00007ff81411db60 CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff81da6b766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff81da6b396 ReceiveNextEventCommon + 199
# 16  HIToolbox                           0x00007ff81da6b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff81726e2f3 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff81726d174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.abi3.so                         0x00000001229224af cvWaitKey + 319
# 20  cv2.abi3.so                         0x000000012291bcb4 _ZN2cv9waitKeyExEi + 148
# 21  cv2.abi3.so                         0x000000012291bd84 _ZN2cv7waitKeyEi + 36
# 22  cv2.abi3.so                         0x0000000121b88014 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  Python                              0x000000010d454b18 cfunction_call_varargs + 120
# 24  Python                              0x000000010d454585 _PyObject_MakeTpCall + 373
# 25  Python                              0x000000010d521835 call_function + 533
# 26  Python                              0x000000010d51e5ed _PyEval_EvalFrameDefault + 25677
# 27  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 28  Python                              0x000000010d5217dc call_function + 444
# 29  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 30  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 31  Python                              0x000000010d5180c4 PyEval_EvalCode + 100
# 32  Python                              0x000000010d5154b2 builtin_exec + 626
# 33  Python                              0x000000010d49081f cfunction_vectorcall_FASTCALL + 175
# 34  Python                              0x000000010d5217dc call_function + 444
# 35  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 36  Python                              0x000000010d4651ae gen_send_ex + 206
# 37  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 38  Python                              0x000000010d4651ae gen_send_ex + 206
# 39  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 40  Python                              0x000000010d4651ae gen_send_ex + 206
# 41  Python                              0x000000010d45df74 method_vectorcall_O + 260
# 42  Python                              0x000000010d5217dc call_function + 444
# 43  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 44  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 45  Python                              0x000000010d5217dc call_function + 444
# 46  Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 47  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 48  Python                              0x000000010d5217dc call_function + 444
# 49  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 50  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 51  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 52  Python                              0x000000010d45767c method_vectorcall + 396
# 53  Python                              0x000000010d4548ad PyVectorcall_Call + 109
# 54  Python                              0x000000010d51eaf8 _PyEval_EvalFrameDefault + 26968
# 55  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 56  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 57  Python                              0x000000010d45759a method_vectorcall + 170
# 58  Python                              0x000000010d5217dc call_function + 444
# 59  Python                              0x000000010d51e714 _PyEval_EvalFrameDefault + 25972
# 60  Python                              0x000000010d4651ae gen_send_ex + 206
# 61  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 62  Python                              0x000000010d4651ae gen_send_ex + 206
# 63  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 64  Python                              0x000000010d4651ae gen_send_ex + 206
# 65  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 66  Python                              0x000000010d4651ae gen_send_ex + 206
# 67  Python                              0x000000010d51a8be _PyEval_EvalFrameDefault + 10014
# 68  Python                              0x000000010d4651ae gen_send_ex + 206
# 69  _asyncio.cpython-38-darwin.so       0x000000010d400ef1 task_step + 833
# 70  _asyncio.cpython-38-darwin.so       0x000000010d400b4e TaskWakeupMethWrapper_call + 430
# 71  Python                              0x000000010d454585 _PyObject_MakeTpCall + 373
# 72  Python                              0x000000010d53e35d context_run + 253
# 73  Python                              0x000000010d4908f4 cfunction_vectorcall_FASTCALL_KEYWORDS + 132
# 74  Python                              0x000000010d4548ad PyVectorcall_Call + 109
# 75  Python                              0x000000010d51ec6b _PyEval_EvalFrameDefault + 27339
# 76  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 77  Python                              0x000000010d5217dc call_function + 444
# 78  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 79  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 80  Python                              0x000000010d5217dc call_function + 444
# 81  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 82  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 83  Python                              0x000000010d5217dc call_function + 444
# 84  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 85  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 86  Python                              0x000000010d5217dc call_function + 444
# 87  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 88  Python                              0x000000010d454ed0 function_code_fastcall + 128
# 89  Python                              0x000000010d5217dc call_function + 444
# 90  Python                              0x000000010d51e5c9 _PyEval_EvalFrameDefault + 25641
# 91  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 92  Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 93  Python                              0x000000010d45759a method_vectorcall + 170
# 94  Python                              0x000000010d5217dc call_function + 444
# 95  Python                              0x000000010d51e5ed _PyEval_EvalFrameDefault + 25677
# 96  Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 97  Python                              0x000000010d5180c4 PyEval_EvalCode + 100
# 98  Python                              0x000000010d5154b2 builtin_exec + 626
# 99  Python                              0x000000010d49081f cfunction_vectorcall_FASTCALL + 175
# 100 Python                              0x000000010d5217dc call_function + 444
# 101 Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 102 Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 103 Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 104 Python                              0x000000010d5217dc call_function + 444
# 105 Python                              0x000000010d51e67a _PyEval_EvalFrameDefault + 25818
# 106 Python                              0x000000010d522624 _PyEval_EvalCodeWithName + 2804
# 107 Python                              0x000000010d45506e _PyFunction_Vectorcall + 270
# 108 Python                              0x000000010d4548ad PyVectorcall_Call + 109
# 109 Python                              0x000000010d584a96 pymain_run_module + 182
# 110 Python                              0x000000010d58405d Py_RunMain + 1085
# 111 Python                              0x000000010d5847cf pymain_main + 223
# 112 Python                              0x000000010d5849cb Py_BytesMain + 43
# 113 dyld                                0x00007ff813d11310 start + 2432
